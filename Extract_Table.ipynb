# %%
# !pip install "camelot-py[cv]" -q

# %%
# !pip install ghostscript

# %%
import ghostscript
import camelot as cam

# %%
import pandas as pd

# %%
pdf = cam.read_pdf("Figs.pdf", pages = "47")
pdf
# Out:
# <TableList n=1>

# %%
table = pdf[0].df
table
# Out:
#       0              1                2              3           4       5   \
# 0
# 1   WELL           DATE             TEST  Interval (ft)        Type     BSW
# 2     B1     March 2001            DST-5      4190-4210  Perforated  0.0025
# 3
# 4     B2  February 2004  Production test      4008-4180    OpenHole     25%
# 5
# 6
# 7          October 2006  Production test      4015-4060  Perforated      0%
# 8     B3     April 2004  Production test      3998-4096    OpenHole     60%
# 9
# 10   B7H     March 2010              PLT             Na    OpenHole     21%
# 11   B9H   October 2007               Na             Na    OpenHole      0%
# 12                                    Na             Na
# 13         January 2010               Na             Na                 32%
# 14  B10H     April 2009  Production test             Na    OpenHole     15%
# 15
# 16  B11H   October 2009               BU             NA    OpenHole     26%
# 17
# ...

# %%
file_name = pd.ExcelWriter('Test.xlsx')
table.to_excel(file_name)
table.to_excel(file_name)
file_name.save()
