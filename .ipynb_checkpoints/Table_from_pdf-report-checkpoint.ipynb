# %%
# !pip install "camelot-py[all]" -q
# !pip install ghostscript

# %%
import ghostscript
import PyPDF2
import camelot as cam

# %%
# !pip install tabula
# !pip install tabula-py

# %%
import tabula.io as tp

# %%
tables= tp.read_pdf("report table.pdf", pages="all")
tables[1]
# Out:
# Got stderr: Sep 26, 2022 2:05:03 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 26, 2022 2:05:03 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 26, 2022 2:05:03 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 26, 2022 2:05:03 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 26, 2022 2:05:03 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# ...

# %%
conda install -c anaconda requests
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install panda
#!pip install requests
#import panda as pd

# %%
#table1 = pdf_test[1].df
#table1

# %%
import tabula
import os

# %%
# save them in a folder
folder_name = "tables"
if not os.path.isdir(folder_name):
    os.mkdir(folder_name)

# %%
# iterate over extracted tables and export as excel individually
for i, table in enumerate(tables, start=1):
    table.to_excel(os.path.join(folder_name, f"table_{i}.xlsx"), index=False)

# %%
# importing the required modules
import glob
import pandas as pd
import os

# %%
path = "C:/New folder/"

filenames = glob.glob(path + "\*.xlsx")
print('File names:', filenames)
# Out:
# File names: ['C:/New folder\\table_1.xlsx', 'C:/New folder\\table_10.xlsx', 'C:/New folder\\table_11.xlsx', 'C:/New folder\\table_12.xlsx', 'C:/New folder\\table_13.xlsx', 'C:/New folder\\table_14.xlsx', 'C:/New folder\\table_15.xlsx', 'C:/New folder\\table_16.xlsx', 'C:/New folder\\table_17.xlsx', 'C:/New folder\\table_18.xlsx', 'C:/New folder\\table_19.xlsx', 'C:/New folder\\table_2.xlsx', 'C:/New folder\\table_20.xlsx', 'C:/New folder\\table_21.xlsx', 'C:/New folder\\table_22.xlsx', 'C:/New folder\\table_23.xlsx', 'C:/New folder\\table_24.xlsx', 'C:/New folder\\table_3.xlsx', 'C:/New folder\\table_4.xlsx', 'C:/New folder\\table_5.xlsx', 'C:/New folder\\table_6.xlsx', 'C:/New folder\\table_7.xlsx', 'C:/New folder\\table_8.xlsx', 'C:/New folder\\table_9.xlsx']

# %%
outputxlsx = pd.DataFrame()

for file in filenames:
   df = pd.concat(pd.read_excel(file, sheet_name=None), ignore_index=True, sort=False)
   outputxlsx = pd.concat(df, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17040/542893441.py in <module>
#       3 for file in filenames:
#       4    df = pd.concat(pd.read_excel(file, sheet_name=None), ignore_index=True, sort=False)
# ----> 5    outputxlsx = pd.concat(df, ignore_index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
# ...

# %%
print('Final Excel sheet now generated at the same location:')
outputxlsx.to_excel("C:/New folder/Output.xlsx", index=False)
# Out:
# Final Excel sheet now generated at the same location:
