# %%
# !pip install "camelot-py[all]" -q
# !pip install ghostscript
# Out:
# Requirement already satisfied: ghostscript in c:\users\zl0423\anaconda3\lib\site-packages (0.7)
# Requirement already satisfied: setuptools>=38.6.0 in c:\users\zl0423\anaconda3\lib\site-packages (from ghostscript) (58.0.4)

# %%
import ghostscript
import PyPDF2
import camelot as cam

# %%
# !pip install tabula
# !pip install tabula-py
# Out:
# Requirement already satisfied: tabula in c:\users\zl0423\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: numpy in c:\users\zl0423\anaconda3\lib\site-packages (from tabula) (1.20.3)
# Requirement already satisfied: setuptools in c:\users\zl0423\anaconda3\lib\site-packages (from tabula) (58.0.4)
# Requirement already satisfied: tabula-py in c:\users\zl0423\anaconda3\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in c:\users\zl0423\anaconda3\lib\site-packages (from tabula-py) (1.20.3)
# Requirement already satisfied: pandas>=0.25.3 in c:\users\zl0423\anaconda3\lib\site-packages (from tabula-py) (1.1.5)
# Requirement already satisfied: distro in c:\users\zl0423\anaconda3\lib\site-packages (from tabula-py) (1.7.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\zl0423\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\zl0423\anaconda3\lib\site-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\zl0423\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.16.0)

# %%
import tabula.io as tp

# %%
tables= tp.read_pdf("report table.pdf", pages="all")
tables[1]
# Out:
# Got stderr: Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 34 (CID 0022) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 39 (CID 0027) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 55 (CID 0037) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 49 (CID 0031) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 52 (CID 0034) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 102 (CID 0066) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 74 (CID 004a) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 58 (CID 003a) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 57 (CID 0039) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 56 (CID 0038) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 52 (CID 0034) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 49 (CID 0031) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 74 (CID 004a) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 53 (CID 0035) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 55 (CID 0037) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 105 (CID 0069) in font HiddenHorzOCR
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:14 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 53 (CID 0035) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 49 (CID 0031) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 58 (CID 003a) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 57 (CID 0039) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 56 (CID 0038) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 111 (CID 006f) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 55 (CID 0037) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 110 (CID 006e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 52 (CID 0034) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 44 (CID 002c) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 84 (CID 0054) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 73 (CID 0049) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 69 (CID 0045) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 45 (CID 002d) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 52 (CID 0034) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 55 (CID 0037) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 49 (CID 0031) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 112 (CID 0070) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 97 (CID 0061) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 114 (CID 0072) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 55 (CID 0037) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 53 (CID 0035) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 58 (CID 003a) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 56 (CID 0038) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 52 (CID 0034) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 183 (CID 00b7) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 49 (CID 0031) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 57 (CID 0039) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 105 (CID 0069) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 56 (CID 0038) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 52 (CID 0034) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 53 (CID 0035) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 41 (CID 0029) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 45 (CID 002d) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 183 (CID 00b7) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 84 (CID 0054) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 73 (CID 0049) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 49 (CID 0031) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 69 (CID 0045) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 48 (CID 0030) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 57 (CID 0039) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 53 (CID 0035) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 58 (CID 003a) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 41 (CID 0029) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 56 (CID 0038) in font HiddenHorzOCR
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:15 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# ...
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 126 (CID 007e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 32 (CID 0020) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 84 (CID 0054) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 73 (CID 0049) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 114 (CID 0072) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 110 (CID 006e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 45 (CID 002d) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 50 (CID 0032) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 46 (CID 002e) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 51 (CID 0033) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 53 (CID 0035) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 57 (CID 0039) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 54 (CID 0036) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 112 (CID 0070) in font HiddenHorzOCR
# Sep 22, 2022 4:25:17 PM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 97 (CID 0061) in font HiddenHorzOCR
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JBIG2 image: jbig2-imageio is not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# Sep 22, 2022 4:25:18 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
#    Unnamed: 0     1235.0 1235.0.1   1128.0        0.39940   6151  5648  5659  \
# 0         NaN     1242.0   1242.0   1135.0        0.40157   6454  5653  5664
# 1         NaN     1249.0   1249.0   1142.0      o. 403'72   6504  5657  5669
# 2         NaN     1256.0   1256.0   1149.0        0.40607   5949  5659  5670
# 3         NaN     1263.0   1263.0   1156.0        0.40835   6151  5662  5673
# 4         NaN     1270.0   1270.0   1163.0        0.41062   6180  5665  5676
# 5         NaN     1277.0   1277.0   1170.0        0.41293   6050  5667  5678
# 6         NaN     1284.0   1284.0   1177.0        0.41529   5927  5668  5680
# 7         NaN    1291. o   1291.0   1184.0        0.41757   6150  5671  5682
# 8         NaN     1298.0   1298.0   1191.0        0.41908   6063  5673  5685
# 9         NaN     1305.0   1305.0   1198.0     0.422:.:.5   6174  5676  5687
# 10        NaN     1312.0   1312.0   1205.0        0.42444   6100  5678  5690
# 11        NaN  1319' . o   1319.0   1212.0        0.42667   6289  5681  5693
# 12        NaN     1326.0   1326.0   1219.0        0.42897   6082  5683  5695
# 13        NaN     1333.0   1333.0   1226.0    o. 4 31.2 9   6029  5685  5697
# 14        NaN     1340.0   1340.0   1233.0        0.433)3   6243  5688  5700
# 15        NaN     1347.0   1347.0   1240.0       0.435'19   6213  5691  5703
# 16        NaN     1354.0   1354.0   1247.0        0.43797   6425  5695  5706
# 17        NaN     1361.0  1361. o   1254.0        0.44017   6364  5698  5710
# 18        NaN     1368.0   1368.0  1261. o      0.442 110   6252  5701  5713
# 19        NaN     1375.0   1375.0   1268.0        0.44470   6088  5703  5715
# 20        NaN     1382.0   1382.0   1275.0        0.44630   6666  5707  5720
# 21        NaN     1389.0   1389.0   1282.0        0.44897   6451  5711  5723
# 22        NaN     1396.0   1396.0   1289.0        0.45130   6006  5712  5725
# 23        NaN     1403.0   1403.0   1296.0        0.45349   6406  5716  5728
# 24        NaN     1410.0   1410.0   1303.0        0.45572   6269  5718  5731
# 25        NaN     1417.0   1417.0   1310.0        0.45801   6120  5720  5733
# 26        NaN     1424.0   1424.0   1317.0     o. 460 :22   6353  5723  5736
# 27        NaN     1431.0   1431.0   1324.0        0.46245   6274  5726  5739
# 28        NaN     1438.0   1438.0   1331.0     o. 464 159   6236  5729  5742
# 29        NaN     1445.0   1445.0   1338.0        0.46690   6341  5731  5745
# 30        NaN     1452.0   1452.0   1345.0        0.46911   6335  5734  5747
# 31        NaN     1459.0   1459.0   1352.0        0.47111   6096  5736  5749
# 32        NaN     1466.0   1466.0   1359.0        0.473'1   6083  5738  5751
# 33        NaN     1473.0   1473.0   1366.0        0.47599   6133  5740  5753
# 34        NaN     1480.0   1480.0   1373.0  o. 4 7 8 ~~ 2   6286  5742  5755
# 35        NaN     1487.0   1487.0   1380.0        0.48046   6232  5744  5758
# 36        NaN     1494.0   1494.0   1387.0        0.48271   6241  5747  5760
# 37         --     1501.0  1501. o   1394.0   o. 4841J3 ~.   6284  5749  5763
# 38        NaN     1508.0   1508.0   1401.0        0.48715   6328  5752  5765
# 39        NaN     1515.0   1515.0   1408.0        0.48963   5648  5751  5765
# 40        NaN     1522.0   1522.0   1415.0     o. 492 .20   5442  5750  5763
# 41        NaN     1529.0   1529.0   1422.0        0.49476   5466  5748  5761
# 42        NaN     1536.0   1536.0   1429.0        0.49650   8041  5756  5771
# 43        NaN     1543.0   1543.0   1436.0        0.498J7   8897  5766  5784
# 44        NaN     1550.0   1550.0   1443.0        0.49997   7382  5772  5790
# 45        NaN     1557.0   1557.0   1450.0        0.50240   5763  5772  5790
# 46        NaN     1564.0   1564.0   1457.0        0.50482   5777  5772  5790
# 47        NaN     1571.0   1571.0   1464.0        0.506S2   8242  5781  5800
# 48        NaN     1578.0   1578.0   1471.0      o. 507~i0  13023  5796  5825
# 49        NaN     1585.0   1585.0   1478.0      o. 5091)4   6841  5800  5829
# 50        NaN     1592.0   1592.0   1485.0        0.51167   6914  5805  5834
# 51        NaN     1599.0   1599.0   1492.0    o. 513 :i 5   8862  5814  5846
# 52        NaN     1606.0   1606.0   1499.0      0.514'-i5  10787  5826  5864
# 53        NaN     1613.0   1613.0   1506.0        0.51670   6504  5829  5866
#
#     14147
# 0   14845
# 1   14959
# 2   13682
# 3   14148
# 4   14213
# 5   13914
# 6   13632
# 7   14146
# 8   13945
# 9   14201
# 10  14029
# 11  14465
# 12  13989
# 13  13867
# 14  14359
# 15  14290
# 16  14778
# 17  14636
# 18  14381
# 19  14003
# 20  15333
# 21  14838
# 22  13814
# 23  14733
# 24  14418
# 25  14076
# 26  14611
# 27  14430
# 28  14344
# 29  14585
# 30  14569
# 31  14022
# 32  13991
# 33  14105
# 34  14459
# 35  14334
# 36  14355
# 37  14453
# 38  14554
# 39  12991
# 40  12516
# 41  12572
# 42  18494
# 43  20464
# 44  16978
# 45  13254
# 46  13286
# 47  18956
# 48  29953
# 49  15735
# 50  15902
# 51  20382
# 52  24811
# 53  14959

# %%
# !pip install panda
# !pip install requests
import panda as pd
# Out:
# Requirement already satisfied: panda in c:\users\zl0423\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: requests in c:\users\zl0423\anaconda3\lib\site-packages (from panda) (2.26.0)
# Requirement already satisfied: setuptools in c:\users\zl0423\anaconda3\lib\site-packages (from panda) (58.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zl0423\anaconda3\lib\site-packages (from requests->panda) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zl0423\anaconda3\lib\site-packages (from requests->panda) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\zl0423\anaconda3\lib\site-packages (from requests->panda) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zl0423\anaconda3\lib\site-packages (from requests->panda) (2021.10.8)
# Requirement already satisfied: requests in c:\users\zl0423\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zl0423\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\zl0423\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zl0423\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\zl0423\anaconda3\lib\site-packages (from requests) (2.0.4)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10304/1015757229.py in <module>
#       1 get_ipython().system('pip install panda')
#       2 get_ipython().system('pip install requests')
# ----> 3 import panda as pd
#
# ~\Anaconda3\lib\site-packages\panda\__init__.py in <module>
# ----> 1 from request import PandaRequest
#       2 from models import Video, Cloud, Encoding, Profile, Notifications, PandaDict
#       3 from models import GroupRetriever, SingleRetriever
#       4 from models import PandaError
#       5 from upload_session import UploadSession
#
# ModuleNotFoundError: No module named 'request'

# %%
conda install -c anaconda requests
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: ...working... done
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\zl0423\Anaconda3
#
#   added / updated specs:
#     - requests
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2022.05  |           py39_0           6 KB  anaconda
#     aiohttp-3.8.1              |   py39h2bbff1b_1         570 KB  anaconda
#     aiosignal-1.2.0            |     pyhd3eb1b0_0          12 KB  anaconda
#     anaconda-custom            |           py39_1           4 KB  anaconda
#     argon2-cffi-bindings-21.2.0|   py39h2bbff1b_0          38 KB  anaconda
#     asttokens-2.0.5            |     pyhd3eb1b0_0          21 KB  anaconda
#     async-timeout-4.0.1        |     pyhd3eb1b0_0          10 KB  anaconda
#     automat-20.2.0             |             py_0          31 KB  anaconda
#     boto3-1.24.2               |   py39haa95532_0         155 KB  anaconda
#     botocore-1.27.2            |   py39haa95532_0         5.7 MB  anaconda
#     ca-certificates-2022.4.26  |       haa95532_0         163 KB  anaconda
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB  anaconda
#     certifi-2022.6.15          |   py39haa95532_0         157 KB  anaconda
#     colorcet-3.0.0             |   py39haa95532_0         1.9 MB  anaconda
#     conda-4.12.0               |   py39haa95532_0        17.0 MB  anaconda
#     constantly-15.1.0          |     pyh2b92418_0           9 KB  anaconda
#     cssselect-1.1.0            |     pyhd3eb1b0_0          17 KB  anaconda
#     datashader-0.13.0          |     pyhd3eb1b0_1        14.3 MB  anaconda
#     datashape-0.5.4            |   py39haa95532_1         102 KB  anaconda
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB  anaconda
#     frozenlist-1.2.0           |   py39h2bbff1b_0          81 KB  anaconda
#     gensim-3.8.3               |   py39hd77b12b_2        22.6 MB  anaconda
#     google-api-core-2.2.2      |     pyhd3eb1b0_0          71 KB  anaconda
#     google-auth-2.6.0          |     pyhd3eb1b0_0          83 KB  anaconda
#     google-cloud-core-2.2.2    |     pyhd3eb1b0_0          27 KB  anaconda
#     google-cloud-storage-1.43.0|   py39haa95532_0         131 KB  anaconda
#     google-crc32c-1.1.2        |   py39h2bbff1b_0          26 KB  anaconda
#     google-resumable-media-1.3.1|     pyhd3eb1b0_1          43 KB  anaconda
#     googleapis-common-protos-1.53.0|   py39h2eaa2aa_0         132 KB  anaconda
#     grpcio-1.42.0              |   py39hc60d5dd_0         2.1 MB  anaconda
#     holoviews-1.14.8           |     pyhd3eb1b0_0         3.5 MB  anaconda
#     hvplot-0.7.3               |     pyhd3eb1b0_1         2.9 MB  anaconda
#     hyperlink-21.0.0           |     pyhd3eb1b0_0          71 KB  anaconda
#     incremental-21.3.0         |     pyhd3eb1b0_0          18 KB  anaconda
#     intake-0.6.5               |     pyhd3eb1b0_0         113 KB  anaconda
#     itemadapter-0.3.0          |     pyhd3eb1b0_0          13 KB  anaconda
#     itemloaders-1.0.4          |     pyhd3eb1b0_1          14 KB  anaconda
#     jmespath-0.10.0            |     pyhd3eb1b0_0          21 KB  anaconda
#     jq-1.6                     |       haa95532_1         1.7 MB  anaconda
#     libcrc32c-1.1.1            |       ha925a31_2          26 KB  anaconda
#     libprotobuf-3.19.1         |       h23ce68f_0         2.4 MB  anaconda
#     markdown-3.3.4             |   py39haa95532_0         144 KB  anaconda
#     multidict-5.1.0            |   py39h2bbff1b_2          63 KB  anaconda
#     openssl-1.1.1o             |       h2bbff1b_0         5.8 MB  anaconda
#     pandas-1.4.2               |   py39hd77b12b_0        11.0 MB  anaconda
#     panel-0.13.0               |   py39haa95532_0        12.8 MB  anaconda
#     param-1.12.0               |     pyhd3eb1b0_0          72 KB  anaconda
#     parsel-1.6.0               |   py39haa95532_0         323 KB  anaconda
#     plotly-5.6.0               |     pyhd3eb1b0_0         6.9 MB  anaconda
#     protego-0.1.16             |             py_0         2.6 MB  anaconda
#     protobuf-3.19.1            |   py39hd77b12b_0         255 KB  anaconda
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB  anaconda
#     pyasn1-0.4.8               |     pyhd3eb1b0_0          54 KB  anaconda
#     pyasn1-modules-0.2.8       |             py_0          67 KB  anaconda
#     pyct-0.4.6                 |   py39haa95532_0          24 KB  anaconda
#     pydispatcher-2.0.5         |   py39haa95532_2          21 KB  anaconda
#     pyhamcrest-2.0.2           |     pyhd3eb1b0_2          30 KB  anaconda
#     python-fastjsonschema-2.15.1|     pyhd3eb1b0_0          27 KB  anaconda
#     python-snappy-0.6.0        |   py39hd77b12b_3          33 KB  anaconda
#     pyviz_comms-2.0.2          |     pyhd3eb1b0_0          25 KB  anaconda
#     queuelib-1.5.0             |   py39haa95532_0         237 KB  anaconda
#     requests-2.27.1            |     pyhd3eb1b0_0          52 KB  anaconda
#     requests-file-1.5.1        |     pyhd3eb1b0_0           7 KB  anaconda
#     rsa-4.7.2                  |     pyhd3eb1b0_1          28 KB  anaconda
#     s3transfer-0.6.0           |   py39haa95532_0         108 KB  anaconda
#     scrapy-2.6.1               |   py39haa95532_0         396 KB  anaconda
#     service_identity-18.1.0    |     pyhd3eb1b0_1          13 KB  anaconda
#     smart_open-5.2.1           |   py39haa95532_0          80 KB  anaconda
#     sqlalchemy-1.4.32          |   py39h2bbff1b_0         2.4 MB  anaconda
#     stack_data-0.2.0           |     pyhd3eb1b0_0          21 KB  anaconda
#     tabulate-0.8.9             |   py39haa95532_0          58 KB  anaconda
#     tenacity-8.0.1             |   py39haa95532_0          35 KB  anaconda
#     tldextract-3.2.0           |     pyhd3eb1b0_0          86 KB  anaconda
#     tomli-1.2.2                |     pyhd3eb1b0_0          17 KB  anaconda
#     twisted-22.2.0             |   py39h2bbff1b_0         5.1 MB  anaconda
#     twisted-iocpsupport-1.0.2  |   py39h2bbff1b_0          50 KB  anaconda
#     typing-extensions-3.10.0.2 |       hd3eb1b0_0          12 KB  anaconda
#     w3lib-1.21.0               |     pyhd3eb1b0_0          21 KB  anaconda
#     websocket-client-0.58.0    |   py39haa95532_4          72 KB  anaconda
#     xarray-0.20.1              |     pyhd3eb1b0_1         623 KB  anaconda
#     yarl-1.6.3                 |   py39h2bbff1b_0         159 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:       125.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  anaconda/win-64::_anaconda_depends-2022.05-py39_0
#   aiohttp            anaconda/win-64::aiohttp-3.8.1-py39h2bbff1b_1
#   aiosignal          anaconda/noarch::aiosignal-1.2.0-pyhd3eb1b0_0
#   argon2-cffi-bindi~ anaconda/win-64::argon2-cffi-bindings-21.2.0-py39h2bbff1b_0
#   asttokens          anaconda/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   async-timeout      anaconda/noarch::async-timeout-4.0.1-pyhd3eb1b0_0
#   automat            anaconda/noarch::automat-20.2.0-py_0
#   boto3              anaconda/win-64::boto3-1.24.2-py39haa95532_0
#   botocore           anaconda/win-64::botocore-1.27.2-py39haa95532_0
#   cachetools         anaconda/noarch::cachetools-4.2.2-pyhd3eb1b0_0
#   colorcet           anaconda/win-64::colorcet-3.0.0-py39haa95532_0
#   constantly         anaconda/noarch::constantly-15.1.0-pyh2b92418_0
#   cssselect          anaconda/noarch::cssselect-1.1.0-pyhd3eb1b0_0
#   datashader         anaconda/noarch::datashader-0.13.0-pyhd3eb1b0_1
#   datashape          anaconda/win-64::datashape-0.5.4-py39haa95532_1
#   executing          anaconda/noarch::executing-0.8.3-pyhd3eb1b0_0
#   frozenlist         anaconda/win-64::frozenlist-1.2.0-py39h2bbff1b_0
#   gensim             anaconda/win-64::gensim-3.8.3-py39hd77b12b_2
#   google-api-core    anaconda/noarch::google-api-core-2.2.2-pyhd3eb1b0_0
#   google-auth        anaconda/noarch::google-auth-2.6.0-pyhd3eb1b0_0
#   google-cloud-core  anaconda/noarch::google-cloud-core-2.2.2-pyhd3eb1b0_0
#   google-cloud-stor~ anaconda/win-64::google-cloud-storage-1.43.0-py39haa95532_0
#   google-crc32c      anaconda/win-64::google-crc32c-1.1.2-py39h2bbff1b_0
#   google-resumable-~ anaconda/noarch::google-resumable-media-1.3.1-pyhd3eb1b0_1
#   googleapis-common~ anaconda/win-64::googleapis-common-protos-1.53.0-py39h2eaa2aa_0
#   grpcio             anaconda/win-64::grpcio-1.42.0-py39hc60d5dd_0
#   holoviews          anaconda/noarch::holoviews-1.14.8-pyhd3eb1b0_0
#   hvplot             anaconda/noarch::hvplot-0.7.3-pyhd3eb1b0_1
#   hyperlink          anaconda/noarch::hyperlink-21.0.0-pyhd3eb1b0_0
#   incremental        anaconda/noarch::incremental-21.3.0-pyhd3eb1b0_0
#   intake             anaconda/noarch::intake-0.6.5-pyhd3eb1b0_0
#   itemadapter        anaconda/noarch::itemadapter-0.3.0-pyhd3eb1b0_0
#   itemloaders        anaconda/noarch::itemloaders-1.0.4-pyhd3eb1b0_1
#   jmespath           anaconda/noarch::jmespath-0.10.0-pyhd3eb1b0_0
#   jq                 anaconda/win-64::jq-1.6-haa95532_1
#   libcrc32c          anaconda/win-64::libcrc32c-1.1.1-ha925a31_2
#   libprotobuf        anaconda/win-64::libprotobuf-3.19.1-h23ce68f_0
#   markdown           anaconda/win-64::markdown-3.3.4-py39haa95532_0
#   multidict          anaconda/win-64::multidict-5.1.0-py39h2bbff1b_2
#   pandas             anaconda/win-64::pandas-1.4.2-py39hd77b12b_0
#   panel              anaconda/win-64::panel-0.13.0-py39haa95532_0
#   param              anaconda/noarch::param-1.12.0-pyhd3eb1b0_0
#   parsel             anaconda/win-64::parsel-1.6.0-py39haa95532_0
#   plotly             anaconda/noarch::plotly-5.6.0-pyhd3eb1b0_0
#   protego            anaconda/noarch::protego-0.1.16-py_0
#   protobuf           anaconda/win-64::protobuf-3.19.1-py39hd77b12b_0
#   pure_eval          anaconda/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pyasn1             anaconda/noarch::pyasn1-0.4.8-pyhd3eb1b0_0
#   pyasn1-modules     anaconda/noarch::pyasn1-modules-0.2.8-py_0
#   pyct               anaconda/win-64::pyct-0.4.6-py39haa95532_0
#   pydispatcher       anaconda/win-64::pydispatcher-2.0.5-py39haa95532_2
#   pyhamcrest         anaconda/noarch::pyhamcrest-2.0.2-pyhd3eb1b0_2
#   python-fastjsonsc~ anaconda/noarch::python-fastjsonschema-2.15.1-pyhd3eb1b0_0
#   python-snappy      anaconda/win-64::python-snappy-0.6.0-py39hd77b12b_3
#   pyviz_comms        anaconda/noarch::pyviz_comms-2.0.2-pyhd3eb1b0_0
#   queuelib           anaconda/win-64::queuelib-1.5.0-py39haa95532_0
#   requests-file      anaconda/noarch::requests-file-1.5.1-pyhd3eb1b0_0
#   rsa                anaconda/noarch::rsa-4.7.2-pyhd3eb1b0_1
#   s3transfer         anaconda/win-64::s3transfer-0.6.0-py39haa95532_0
#   scrapy             anaconda/win-64::scrapy-2.6.1-py39haa95532_0
#   service_identity   anaconda/noarch::service_identity-18.1.0-pyhd3eb1b0_1
#   smart_open         anaconda/win-64::smart_open-5.2.1-py39haa95532_0
#   sqlalchemy         anaconda/win-64::sqlalchemy-1.4.32-py39h2bbff1b_0
#   stack_data         anaconda/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   tabulate           anaconda/win-64::tabulate-0.8.9-py39haa95532_0
#   tenacity           anaconda/win-64::tenacity-8.0.1-py39haa95532_0
#   tldextract         anaconda/noarch::tldextract-3.2.0-pyhd3eb1b0_0
#   tomli              anaconda/noarch::tomli-1.2.2-pyhd3eb1b0_0
#   twisted            anaconda/win-64::twisted-22.2.0-py39h2bbff1b_0
#   twisted-iocpsuppo~ anaconda/win-64::twisted-iocpsupport-1.0.2-py39h2bbff1b_0
#   typing-extensions  anaconda/noarch::typing-extensions-3.10.0.2-hd3eb1b0_0
#   w3lib              anaconda/noarch::w3lib-1.21.0-pyhd3eb1b0_0
#   websocket-client   anaconda/win-64::websocket-client-0.58.0-py39haa95532_4
#   xarray             anaconda/noarch::xarray-0.20.1-pyhd3eb1b0_1
#   yarl               anaconda/win-64::yarl-1.6.3-py39h2bbff1b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.10.26~ --> anaconda::ca-certificates-2022.4.26-haa95532_0
#   certifi            pkgs/main::certifi-2021.10.8-py39haa9~ --> anaconda::certifi-2022.6.15-py39haa95532_0
#   openssl              pkgs/main::openssl-1.1.1l-h2bbff1b_0 --> anaconda::openssl-1.1.1o-h2bbff1b_0
#   requests           pkgs/main::requests-2.26.0-pyhd3eb1b0~ --> anaconda::requests-2.27.1-pyhd3eb1b0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   anaconda               pkgs/main::anaconda-2021.11-py39_0 --> anaconda::anaconda-custom-py39_1
#   conda                                           pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
#
# Note: you may need to restart the kernel to use updated packages.tomli-1.2.2          | 17 KB     |            |   0%
# tomli-1.2.2          | 17 KB     | #########1 |  92%
# tomli-1.2.2          | 17 KB     | ########## | 100%
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.11=py39_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/win-64::statsmodels==0.12.2=py39h2bbff1b_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==2021.11=py39_0
#   - defaults/win-64::bkcharts==0.2=py39haa95532_0
#   - defaults/noarch::dask==2021.10.0=pyhd3eb1b0_0
#   - defaults/noarch::seaborn==0.11.2=pyhd3eb1b0_0
#   - defaults/win-64::statsmodels==0.12.2=py39h2bbff1b_0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 4.14.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# google-cloud-storage | 131 KB    |            |   0%
# google-cloud-storage | 131 KB    | #2         |  12%
# google-cloud-storage | 131 KB    | ########## | 100%
#
# datashader-0.13.0    | 14.3 MB   |            |   0%
# datashader-0.13.0    | 14.3 MB   |            |   0%
# datashader-0.13.0    | 14.3 MB   | 9          |  10%
# datashader-0.13.0    | 14.3 MB   | ##6        |  26%
# datashader-0.13.0    | 14.3 MB   | ###8       |  39%
# datashader-0.13.0    | 14.3 MB   | ####6      |  47%
# datashader-0.13.0    | 14.3 MB   | #####3     |  53%
# datashader-0.13.0    | 14.3 MB   | #####9     |  59%
# datashader-0.13.0    | 14.3 MB   | ######4    |  64%
# datashader-0.13.0    | 14.3 MB   | ######9    |  69%
# datashader-0.13.0    | 14.3 MB   | #######4   |  75%
# datashader-0.13.0    | 14.3 MB   | #######9   |  79%
# datashader-0.13.0    | 14.3 MB   | ########5  |  86%
# datashader-0.13.0    | 14.3 MB   | #########  |  90%
# datashader-0.13.0    | 14.3 MB   | #########4 |  95%
# datashader-0.13.0    | 14.3 MB   | #########9 |  99%
# datashader-0.13.0    | 14.3 MB   | ########## | 100%
#
# service_identity-18. | 13 KB     |            |   0%
# service_identity-18. | 13 KB     | ########## | 100%
# service_identity-18. | 13 KB     | ########## | 100%
#
# cachetools-4.2.2     | 13 KB     |            |   0%
# cachetools-4.2.2     | 13 KB     | ########## | 100%
# cachetools-4.2.2     | 13 KB     | ########## | 100%
#
# constantly-15.1.0    | 9 KB      |            |   0%
# constantly-15.1.0    | 9 KB      | ########## | 100%
# constantly-15.1.0    | 9 KB      | ########## | 100%
#
# pydispatcher-2.0.5   | 21 KB     |            |   0%
# pydispatcher-2.0.5   | 21 KB     | #######7   |  78%
# pydispatcher-2.0.5   | 21 KB     | ########## | 100%
#
# hyperlink-21.0.0     | 71 KB     |            |   0%
# hyperlink-21.0.0     | 71 KB     | ##2        |  22%
# hyperlink-21.0.0     | 71 KB     | ########## | 100%
#
# tabulate-0.8.9       | 58 KB     |            |   0%
# tabulate-0.8.9       | 58 KB     | ##7        |  28%
# tabulate-0.8.9       | 58 KB     | ########## | 100%
#
# cssselect-1.1.0      | 17 KB     |            |   0%
# cssselect-1.1.0      | 17 KB     | #########3 |  94%
# cssselect-1.1.0      | 17 KB     | ########## | 100%
#
# conda-4.12.0         | 17.0 MB   |            |   0%
# conda-4.12.0         | 17.0 MB   |            |   0%
# conda-4.12.0         | 17.0 MB   |            |   0%
# conda-4.12.0         | 17.0 MB   | 1          |   2%
# conda-4.12.0         | 17.0 MB   | 4          |   4%
# conda-4.12.0         | 17.0 MB   | 6          |   6%
# conda-4.12.0         | 17.0 MB   | #1         |  11%
# conda-4.12.0         | 17.0 MB   | #9         |  19%
# conda-4.12.0         | 17.0 MB   | ##9        |  29%
# conda-4.12.0         | 17.0 MB   | ###9       |  40%
# conda-4.12.0         | 17.0 MB   | #####2     |  52%
# conda-4.12.0         | 17.0 MB   | #####9     |  59%
# conda-4.12.0         | 17.0 MB   | ######5    |  65%
# conda-4.12.0         | 17.0 MB   | #######    |  70%
# conda-4.12.0         | 17.0 MB   | #######5   |  75%
# conda-4.12.0         | 17.0 MB   | #######9   |  79%
# conda-4.12.0         | 17.0 MB   | ########3  |  83%
# conda-4.12.0         | 17.0 MB   | ########7  |  87%
# conda-4.12.0         | 17.0 MB   | #########1 |  91%
# conda-4.12.0         | 17.0 MB   | #########4 |  95%
# conda-4.12.0         | 17.0 MB   | #########8 |  99%
# conda-4.12.0         | 17.0 MB   | ########## | 100%
#
# google-resumable-med | 43 KB     |            |   0%
# google-resumable-med | 43 KB     | ###7       |  37%
# google-resumable-med | 43 KB     | ########## | 100%
#
# twisted-iocpsupport- | 50 KB     |            |   0%
# twisted-iocpsupport- | 50 KB     | ###2       |  32%
# twisted-iocpsupport- | 50 KB     | ########## | 100%
#
# anaconda-custom      | 4 KB      |            |   0%
# anaconda-custom      | 4 KB      | ########## | 100%
# anaconda-custom      | 4 KB      | ########## | 100%
#
# google-api-core-2.2. | 71 KB     |            |   0%
# google-api-core-2.2. | 71 KB     | ##2        |  23%
# google-api-core-2.2. | 71 KB     | ########## | 100%
#
# pyviz_comms-2.0.2    | 25 KB     |            |   0%
# pyviz_comms-2.0.2    | 25 KB     | ######4    |  64%
# pyviz_comms-2.0.2    | 25 KB     | ########## | 100%
#
# python-snappy-0.6.0  | 33 KB     |            |   0%
# python-snappy-0.6.0  | 33 KB     | ####8      |  49%
# python-snappy-0.6.0  | 33 KB     | ########## | 100%
#
# requests-file-1.5.1  | 7 KB      |            |   0%
# requests-file-1.5.1  | 7 KB      | ########## | 100%
# requests-file-1.5.1  | 7 KB      | ########## | 100%
#
# frozenlist-1.2.0     | 81 KB     |            |   0%
# frozenlist-1.2.0     | 81 KB     | #9         |  20%
# frozenlist-1.2.0     | 81 KB     | ########## | 100%
#
# intake-0.6.5         | 113 KB    |            |   0%
# intake-0.6.5         | 113 KB    | #4         |  14%
# intake-0.6.5         | 113 KB    | ########## | 100%
# intake-0.6.5         | 113 KB    | ########## | 100%
#
# plotly-5.6.0         | 6.9 MB    |            |   0%
# plotly-5.6.0         | 6.9 MB    |            |   0%
# plotly-5.6.0         | 6.9 MB    | 7          |   7%
# plotly-5.6.0         | 6.9 MB    | #6         |  17%
# plotly-5.6.0         | 6.9 MB    | ###3       |  33%
# plotly-5.6.0         | 6.9 MB    | #####6     |  57%
# plotly-5.6.0         | 6.9 MB    | ########4  |  84%
# plotly-5.6.0         | 6.9 MB    | ########## | 100%
#
# aiohttp-3.8.1        | 570 KB    |            |   0%
# aiohttp-3.8.1        | 570 KB    | 2          |   3%
# aiohttp-3.8.1        | 570 KB    | ########## | 100%
# aiohttp-3.8.1        | 570 KB    | ########## | 100%
#
# protobuf-3.19.1      | 255 KB    |            |   0%
# protobuf-3.19.1      | 255 KB    | 6          |   6%
# protobuf-3.19.1      | 255 KB    | ########## | 100%
# protobuf-3.19.1      | 255 KB    | ########## | 100%
#
# aiosignal-1.2.0      | 12 KB     |            |   0%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
# aiosignal-1.2.0      | 12 KB     | ########## | 100%
#
# queuelib-1.5.0       | 237 KB    |            |   0%
# queuelib-1.5.0       | 237 KB    | 6          |   7%
# queuelib-1.5.0       | 237 KB    | ########## | 100%
#
# certifi-2022.6.15    | 157 KB    |            |   0%
# certifi-2022.6.15    | 157 KB    | #          |  10%
# certifi-2022.6.15    | 157 KB    | ########## | 100%
#
# botocore-1.27.2      | 5.7 MB    |            |   0%
# botocore-1.27.2      | 5.7 MB    |            |   0%
# botocore-1.27.2      | 5.7 MB    | 3          |   3%
# botocore-1.27.2      | 5.7 MB    | 6          |   7%
# botocore-1.27.2      | 5.7 MB    | #4         |  14%
# botocore-1.27.2      | 5.7 MB    | ##8        |  28%
# botocore-1.27.2      | 5.7 MB    | #####8     |  59%
# botocore-1.27.2      | 5.7 MB    | #########2 |  93%
# botocore-1.27.2      | 5.7 MB    | ########## | 100%
#
# datashape-0.5.4      | 102 KB    |            |   0%
# datashape-0.5.4      | 102 KB    | #5         |  16%
# datashape-0.5.4      | 102 KB    | ########## | 100%
#
# markdown-3.3.4       | 144 KB    |            |   0%
# markdown-3.3.4       | 144 KB    | #1         |  11%
# markdown-3.3.4       | 144 KB    | ########## | 100%
#
# _anaconda_depends-20 | 6 KB      |            |   0%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
# _anaconda_depends-20 | 6 KB      | ########## | 100%
#
# tldextract-3.2.0     | 86 KB     |            |   0%
# tldextract-3.2.0     | 86 KB     | #8         |  19%
# tldextract-3.2.0     | 86 KB     | ########## | 100%
#
# requests-2.27.1      | 52 KB     |            |   0%
# requests-2.27.1      | 52 KB     | ########## | 100%
# requests-2.27.1      | 52 KB     | ########## | 100%
#
# libprotobuf-3.19.1   | 2.4 MB    |            |   0%
# libprotobuf-3.19.1   | 2.4 MB    |            |   1%
# libprotobuf-3.19.1   | 2.4 MB    | #####1     |  51%
# libprotobuf-3.19.1   | 2.4 MB    | ########## | 100%
# libprotobuf-3.19.1   | 2.4 MB    | ########## | 100%
#
# stack_data-0.2.0     | 21 KB     |            |   0%
# stack_data-0.2.0     | 21 KB     | ########## | 100%
#
# xarray-0.20.1        | 623 KB    |            |   0%
# xarray-0.20.1        | 623 KB    | 2          |   3%
# xarray-0.20.1        | 623 KB    | ########## | 100%
# xarray-0.20.1        | 623 KB    | ########## | 100%
#
# google-crc32c-1.1.2  | 26 KB     |            |   0%
# google-crc32c-1.1.2  | 26 KB     | ######     |  61%
# google-crc32c-1.1.2  | 26 KB     | ########## | 100%
#
# automat-20.2.0       | 31 KB     |            |   0%
# automat-20.2.0       | 31 KB     | #####2     |  52%
# automat-20.2.0       | 31 KB     | ########## | 100%
#
# pyhamcrest-2.0.2     | 30 KB     |            |   0%
# pyhamcrest-2.0.2     | 30 KB     | #####4     |  54%
# pyhamcrest-2.0.2     | 30 KB     | ########## | 100%
#
# asttokens-2.0.5      | 21 KB     |            |   0%
# asttokens-2.0.5      | 21 KB     | ########## | 100%
# asttokens-2.0.5      | 21 KB     | ########## | 100%
#
# itemloaders-1.0.4    | 14 KB     |            |   0%
# itemloaders-1.0.4    | 14 KB     | ########## | 100%
# itemloaders-1.0.4    | 14 KB     | ########## | 100%
#
# ca-certificates-2022 | 163 KB    |            |   0%
# ca-certificates-2022 | 163 KB    | ########## | 100%
#
# s3transfer-0.6.0     | 108 KB    |            |   0%
# s3transfer-0.6.0     | 108 KB    | #4         |  15%
# s3transfer-0.6.0     | 108 KB    | ########## | 100%
#
# async-timeout-4.0.1  | 10 KB     |            |   0%
# async-timeout-4.0.1  | 10 KB     | ########## | 100%
# async-timeout-4.0.1  | 10 KB     | ########## | 100%
#
# incremental-21.3.0   | 18 KB     |            |   0%
# incremental-21.3.0   | 18 KB     | ########9  |  90%
# incremental-21.3.0   | 18 KB     | ########## | 100%
#
# parsel-1.6.0         | 323 KB    |            |   0%
# parsel-1.6.0         | 323 KB    | 4          |   5%
# parsel-1.6.0         | 323 KB    | ######9    |  69%
# parsel-1.6.0         | 323 KB    | ########## | 100%
#
# tenacity-8.0.1       | 35 KB     |            |   0%
# tenacity-8.0.1       | 35 KB     | ####5      |  46%
# tenacity-8.0.1       | 35 KB     | ########## | 100%
#
# google-auth-2.6.0    | 83 KB     |            |   0%
# google-auth-2.6.0    | 83 KB     | #9         |  19%
# google-auth-2.6.0    | 83 KB     | ########## | 100%
#
# twisted-22.2.0       | 5.1 MB    |            |   0%
# twisted-22.2.0       | 5.1 MB    |            |   0%
# twisted-22.2.0       | 5.1 MB    | 3          |   4%
# twisted-22.2.0       | 5.1 MB    | #          |  11%
# twisted-22.2.0       | 5.1 MB    | ##5        |  25%
# twisted-22.2.0       | 5.1 MB    | #####      |  51%
# twisted-22.2.0       | 5.1 MB    | #########3 |  93%
# twisted-22.2.0       | 5.1 MB    | ########## | 100%
#
# panel-0.13.0         | 12.8 MB   |            |   0%
# panel-0.13.0         | 12.8 MB   |            |   0%
# panel-0.13.0         | 12.8 MB   |            |   1%
# panel-0.13.0         | 12.8 MB   | 1          |   2%
# panel-0.13.0         | 12.8 MB   | 5          |   6%
# panel-0.13.0         | 12.8 MB   | #3         |  13%
# panel-0.13.0         | 12.8 MB   | ##6        |  27%
# panel-0.13.0         | 12.8 MB   | ###8       |  38%
# panel-0.13.0         | 12.8 MB   | ####6      |  47%
# panel-0.13.0         | 12.8 MB   | ######5    |  66%
# panel-0.13.0         | 12.8 MB   | #######5   |  76%
# panel-0.13.0         | 12.8 MB   | ########4  |  84%
# panel-0.13.0         | 12.8 MB   | #########1 |  91%
# panel-0.13.0         | 12.8 MB   | #########7 |  98%
# panel-0.13.0         | 12.8 MB   | ########## | 100%
#
# protego-0.1.16       | 2.6 MB    |            |   0%
# protego-0.1.16       | 2.6 MB    |            |   1%
# protego-0.1.16       | 2.6 MB    | ##2        |  23%
# protego-0.1.16       | 2.6 MB    | ####8      |  48%
# protego-0.1.16       | 2.6 MB    | #######4   |  74%
# protego-0.1.16       | 2.6 MB    | #########7 |  97%
# protego-0.1.16       | 2.6 MB    | ########## | 100%
#
# pandas-1.4.2         | 11.0 MB   |            |   0%
# pandas-1.4.2         | 11.0 MB   |            |   0%
# pandas-1.4.2         | 11.0 MB   | 1          |   2%
# pandas-1.4.2         | 11.0 MB   | 2          |   3%
# pandas-1.4.2         | 11.0 MB   | 3          |   4%
# pandas-1.4.2         | 11.0 MB   | 5          |   5%
# pandas-1.4.2         | 11.0 MB   | 6          |   6%
# pandas-1.4.2         | 11.0 MB   | 7          |   7%
# pandas-1.4.2         | 11.0 MB   | 8          |   8%
# pandas-1.4.2         | 11.0 MB   | #          |  11%
# pandas-1.4.2         | 11.0 MB   | #2         |  12%
# pandas-1.4.2         | 11.0 MB   | #4         |  14%
# pandas-1.4.2         | 11.0 MB   | #5         |  16%
# pandas-1.4.2         | 11.0 MB   | #7         |  17%
# pandas-1.4.2         | 11.0 MB   | #8         |  19%
# pandas-1.4.2         | 11.0 MB   | ##         |  20%
# pandas-1.4.2         | 11.0 MB   | ##1        |  22%
# pandas-1.4.2         | 11.0 MB   | ##2        |  23%
# pandas-1.4.2         | 11.0 MB   | ##4        |  24%
# pandas-1.4.2         | 11.0 MB   | ##5        |  26%
# pandas-1.4.2         | 11.0 MB   | ##7        |  27%
# pandas-1.4.2         | 11.0 MB   | ##8        |  29%
# pandas-1.4.2         | 11.0 MB   | ###        |  30%
# pandas-1.4.2         | 11.0 MB   | ###1       |  32%
# pandas-1.4.2         | 11.0 MB   | ###3       |  33%
# pandas-1.4.2         | 11.0 MB   | ###4       |  35%
# pandas-1.4.2         | 11.0 MB   | ###5       |  36%
# pandas-1.4.2         | 11.0 MB   | ###7       |  37%
# pandas-1.4.2         | 11.0 MB   | ###9       |  39%
# pandas-1.4.2         | 11.0 MB   | ####       |  41%
# pandas-1.4.2         | 11.0 MB   | ####2      |  42%
# pandas-1.4.2         | 11.0 MB   | ####3      |  44%
# pandas-1.4.2         | 11.0 MB   | ####5      |  46%
# pandas-1.4.2         | 11.0 MB   | ####6      |  47%
# pandas-1.4.2         | 11.0 MB   | ####8      |  48%
# pandas-1.4.2         | 11.0 MB   | ####9      |  50%
# pandas-1.4.2         | 11.0 MB   | #####1     |  52%
# pandas-1.4.2         | 11.0 MB   | #####3     |  53%
# pandas-1.4.2         | 11.0 MB   | #####5     |  55%
# pandas-1.4.2         | 11.0 MB   | #####6     |  57%
# pandas-1.4.2         | 11.0 MB   | #####8     |  58%
# pandas-1.4.2         | 11.0 MB   | #####9     |  60%
# pandas-1.4.2         | 11.0 MB   | ######1    |  61%
# pandas-1.4.2         | 11.0 MB   | ######3    |  63%
# pandas-1.4.2         | 11.0 MB   | ######4    |  65%
# pandas-1.4.2         | 11.0 MB   | ######5    |  66%
# pandas-1.4.2         | 11.0 MB   | ######7    |  67%
# pandas-1.4.2         | 11.0 MB   | ######8    |  69%
# pandas-1.4.2         | 11.0 MB   | #######    |  70%
# pandas-1.4.2         | 11.0 MB   | #######1   |  72%
# pandas-1.4.2         | 11.0 MB   | #######2   |  73%
# pandas-1.4.2         | 11.0 MB   | #######4   |  75%
# pandas-1.4.2         | 11.0 MB   | #######6   |  76%
# pandas-1.4.2         | 11.0 MB   | #######7   |  78%
# pandas-1.4.2         | 11.0 MB   | #######8   |  79%
# pandas-1.4.2         | 11.0 MB   | ########   |  80%
# pandas-1.4.2         | 11.0 MB   | ########1  |  82%
# pandas-1.4.2         | 11.0 MB   | ########3  |  83%
# pandas-1.4.2         | 11.0 MB   | ########5  |  85%
# pandas-1.4.2         | 11.0 MB   | ########6  |  87%
# pandas-1.4.2         | 11.0 MB   | ########8  |  88%
# pandas-1.4.2         | 11.0 MB   | ########9  |  90%
# pandas-1.4.2         | 11.0 MB   | #########1 |  91%
# pandas-1.4.2         | 11.0 MB   | #########2 |  93%
# pandas-1.4.2         | 11.0 MB   | #########4 |  94%
# pandas-1.4.2         | 11.0 MB   | #########5 |  95%
# pandas-1.4.2         | 11.0 MB   | #########7 |  97%
# pandas-1.4.2         | 11.0 MB   | #########8 |  99%
# pandas-1.4.2         | 11.0 MB   | ########## | 100%
#
# scrapy-2.6.1         | 396 KB    |            |   0%
# scrapy-2.6.1         | 396 KB    | 4          |   4%
# scrapy-2.6.1         | 396 KB    | ########## | 100%
# scrapy-2.6.1         | 396 KB    | ########## | 100%
#
# boto3-1.24.2         | 155 KB    |            |   0%
# boto3-1.24.2         | 155 KB    | #          |  10%
# boto3-1.24.2         | 155 KB    | ########## | 100%
#
# jmespath-0.10.0      | 21 KB     |            |   0%
# jmespath-0.10.0      | 21 KB     | #######5   |  76%
# jmespath-0.10.0      | 21 KB     | ########## | 100%
#
# colorcet-3.0.0       | 1.9 MB    |            |   0%
# colorcet-3.0.0       | 1.9 MB    |            |   1%
# colorcet-3.0.0       | 1.9 MB    | 9          |  10%
# colorcet-3.0.0       | 1.9 MB    | ##9        |  30%
# colorcet-3.0.0       | 1.9 MB    | ######     |  60%
# colorcet-3.0.0       | 1.9 MB    | ########## | 100%
# colorcet-3.0.0       | 1.9 MB    | ########## | 100%
#
# argon2-cffi-bindings | 38 KB     |            |   0%
# argon2-cffi-bindings | 38 KB     | ####1      |  42%
# argon2-cffi-bindings | 38 KB     | ########## | 100%
#
# pyasn1-0.4.8         | 54 KB     |            |   0%
# pyasn1-0.4.8         | 54 KB     | ##9        |  30%
# pyasn1-0.4.8         | 54 KB     | ########## | 100%
#
# executing-0.8.3      | 18 KB     |            |   0%
# executing-0.8.3      | 18 KB     | ########## | 100%
# executing-0.8.3      | 18 KB     | ########## | 100%
#
# multidict-5.1.0      | 63 KB     |            |   0%
# multidict-5.1.0      | 63 KB     | ##5        |  25%
# multidict-5.1.0      | 63 KB     | ########## | 100%
#
# sqlalchemy-1.4.32    | 2.4 MB    |            |   0%
# sqlalchemy-1.4.32    | 2.4 MB    |            |   1%
# sqlalchemy-1.4.32    | 2.4 MB    | 5          |   6%
# sqlalchemy-1.4.32    | 2.4 MB    | #1         |  12%
# sqlalchemy-1.4.32    | 2.4 MB    | ##1        |  22%
# sqlalchemy-1.4.32    | 2.4 MB    | ###1       |  31%
# sqlalchemy-1.4.32    | 2.4 MB    | ###9       |  39%
# sqlalchemy-1.4.32    | 2.4 MB    | ####5      |  45%
# sqlalchemy-1.4.32    | 2.4 MB    | #####1     |  51%
# sqlalchemy-1.4.32    | 2.4 MB    | #####7     |  58%
# sqlalchemy-1.4.32    | 2.4 MB    | ######4    |  64%
# sqlalchemy-1.4.32    | 2.4 MB    | #######    |  71%
# sqlalchemy-1.4.32    | 2.4 MB    | #######7   |  78%
# sqlalchemy-1.4.32    | 2.4 MB    | ########4  |  85%
# sqlalchemy-1.4.32    | 2.4 MB    | #########1 |  92%
# sqlalchemy-1.4.32    | 2.4 MB    | ########## | 100%
# sqlalchemy-1.4.32    | 2.4 MB    | ########## | 100%
#
# jq-1.6               | 1.7 MB    |            |   0%
# jq-1.6               | 1.7 MB    |            |   1%
# jq-1.6               | 1.7 MB    | #########2 |  93%
# jq-1.6               | 1.7 MB    | ########## | 100%
#
# pyasn1-modules-0.2.8 | 67 KB     |            |   0%
# pyasn1-modules-0.2.8 | 67 KB     | ##3        |  24%
# pyasn1-modules-0.2.8 | 67 KB     | ########## | 100%
#
# holoviews-1.14.8     | 3.5 MB    |            |   0%
# holoviews-1.14.8     | 3.5 MB    |            |   0%
# holoviews-1.14.8     | 3.5 MB    | ####8      |  49%
# holoviews-1.14.8     | 3.5 MB    | ########## | 100%
# holoviews-1.14.8     | 3.5 MB    | ########## | 100%
#
# websocket-client-0.5 | 72 KB     |            |   0%
# websocket-client-0.5 | 72 KB     | ##2        |  22%
# websocket-client-0.5 | 72 KB     | ########## | 100%
#
# smart_open-5.2.1     | 80 KB     |            |   0%
# smart_open-5.2.1     | 80 KB     | #9         |  20%
# smart_open-5.2.1     | 80 KB     | ########## | 100%
#
# grpcio-1.42.0        | 2.1 MB    |            |   0%
# grpcio-1.42.0        | 2.1 MB    |            |   1%
# grpcio-1.42.0        | 2.1 MB    | 7          |   7%
# grpcio-1.42.0        | 2.1 MB    | #3         |  13%
# grpcio-1.42.0        | 2.1 MB    | ##         |  20%
# grpcio-1.42.0        | 2.1 MB    | ##9        |  30%
# grpcio-1.42.0        | 2.1 MB    | ###8       |  39%
# grpcio-1.42.0        | 2.1 MB    | ####8      |  49%
# grpcio-1.42.0        | 2.1 MB    | #######3   |  73%
# grpcio-1.42.0        | 2.1 MB    | ########## | 100%
# grpcio-1.42.0        | 2.1 MB    | ########## | 100%
#
# param-1.12.0         | 72 KB     |            |   0%
# param-1.12.0         | 72 KB     | ##2        |  22%
# param-1.12.0         | 72 KB     | ########## | 100%
#
# rsa-4.7.2            | 28 KB     |            |   0%
# rsa-4.7.2            | 28 KB     | #####7     |  57%
# rsa-4.7.2            | 28 KB     | ########## | 100%
#
# yarl-1.6.3           | 159 KB    |            |   0%
# yarl-1.6.3           | 159 KB    | #          |  10%
# yarl-1.6.3           | 159 KB    | ########## | 100%
#
# w3lib-1.21.0         | 21 KB     |            |   0%
# w3lib-1.21.0         | 21 KB     | #######5   |  75%
# w3lib-1.21.0         | 21 KB     | ########## | 100%
#
# typing-extensions-3. | 12 KB     |            |   0%
# typing-extensions-3. | 12 KB     | ########## | 100%
# typing-extensions-3. | 12 KB     | ########## | 100%
#
# libcrc32c-1.1.1      | 26 KB     |            |   0%
# libcrc32c-1.1.1      | 26 KB     | ######     |  61%
# libcrc32c-1.1.1      | 26 KB     | ########## | 100%
#
# google-cloud-core-2. | 27 KB     |            |   0%
# google-cloud-core-2. | 27 KB     | ######     |  60%
# google-cloud-core-2. | 27 KB     | ########## | 100%
#
# openssl-1.1.1o       | 5.8 MB    |            |   0%
# openssl-1.1.1o       | 5.8 MB    | ##2        |  23%
# openssl-1.1.1o       | 5.8 MB    | #####9     |  59%
# openssl-1.1.1o       | 5.8 MB    | ########7  |  87%
# openssl-1.1.1o       | 5.8 MB    | ########## | 100%
#
# python-fastjsonschem | 27 KB     |            |   0%
# python-fastjsonschem | 27 KB     | ########## | 100%
#
# gensim-3.8.3         | 22.6 MB   |            |   0%
# gensim-3.8.3         | 22.6 MB   |            |   0%
# gensim-3.8.3         | 22.6 MB   | #2         |  12%
# gensim-3.8.3         | 22.6 MB   | #8         |  18%
# gensim-3.8.3         | 22.6 MB   | ##9        |  29%
# gensim-3.8.3         | 22.6 MB   | ###5       |  36%
# gensim-3.8.3         | 22.6 MB   | ####       |  40%
# gensim-3.8.3         | 22.6 MB   | ####4      |  45%
# gensim-3.8.3         | 22.6 MB   | ####8      |  49%
# gensim-3.8.3         | 22.6 MB   | #####2     |  52%
# gensim-3.8.3         | 22.6 MB   | #####5     |  55%
# gensim-3.8.3         | 22.6 MB   | #####8     |  58%
# gensim-3.8.3         | 22.6 MB   | ######1    |  61%
# gensim-3.8.3         | 22.6 MB   | ######4    |  64%
# gensim-3.8.3         | 22.6 MB   | ######7    |  67%
# gensim-3.8.3         | 22.6 MB   | #######    |  70%
# gensim-3.8.3         | 22.6 MB   | #######2   |  73%
# gensim-3.8.3         | 22.6 MB   | #######5   |  75%
# gensim-3.8.3         | 22.6 MB   | #######8   |  79%
# gensim-3.8.3         | 22.6 MB   | ########1  |  82%
# gensim-3.8.3         | 22.6 MB   | ########4  |  85%
# gensim-3.8.3         | 22.6 MB   | ########8  |  88%
# gensim-3.8.3         | 22.6 MB   | #########1 |  91%
# gensim-3.8.3         | 22.6 MB   | #########4 |  94%
# gensim-3.8.3         | 22.6 MB   | #########6 |  97%
# gensim-3.8.3         | 22.6 MB   | #########9 | 100%
# gensim-3.8.3         | 22.6 MB   | ########## | 100%
#
# pyct-0.4.6           | 24 KB     |            |   0%
# pyct-0.4.6           | 24 KB     | ######5    |  66%
# pyct-0.4.6           | 24 KB     | ########## | 100%
#
# hvplot-0.7.3         | 2.9 MB    |            |   0%
# hvplot-0.7.3         | 2.9 MB    |            |   1%
# hvplot-0.7.3         | 2.9 MB    | #9         |  20%
# hvplot-0.7.3         | 2.9 MB    | ###7       |  37%
# hvplot-0.7.3         | 2.9 MB    | #######3   |  74%
# hvplot-0.7.3         | 2.9 MB    | ########## | 100%
# hvplot-0.7.3         | 2.9 MB    | ########## | 100%
#
# googleapis-common-pr | 132 KB    |            |   0%
# googleapis-common-pr | 132 KB    | #2         |  12%
# googleapis-common-pr | 132 KB    | ########## | 100%
# googleapis-common-pr | 132 KB    | ########## | 100%
#
# itemadapter-0.3.0    | 13 KB     |            |   0%
# itemadapter-0.3.0    | 13 KB     | ########## | 100%
# itemadapter-0.3.0    | 13 KB     | ########## | 100%
#
# pure_eval-0.2.2      | 14 KB     |            |   0%
# pure_eval-0.2.2      | 14 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
#table1 = pdf_test[1].df
#table1

# %%
import tabula
import os

# %%
# save them in a folder
folder_name = "tables"
if not os.path.isdir(folder_name):
    os.mkdir(folder_name)

# %%
# iterate over extracted tables and export as excel individually
for i, table in enumerate(tables, start=1):
    table.to_excel(os.path.join(folder_name, f"table_{i}.xlsx"), index=False)

# %%
# importing the required modules
#import glob
#import pandas as pd
 
# specifying the path to csv files
#path = "C:/downloads"
 
# csv files in the path
#file_list = glob.glob(path + "/*.xlsx")
 
# list of excel files we want to merge.
# pd.read_excel(file_path) reads the excel
# data into pandas dataframe.
#excl_list = []
 
#for file in file_list:
#    excl_list.append(pd.read_excel(file))
 
# create a new dataframe to store the
# merged excel file.
#excl_merged = pd.DataFrame()
 
#for excl_file in excl_list:
     
    # appends the data into the excl_merged
    # dataframe.
#    excl_merged = excl_merged.append(
#      excl_file, ignore_index=True)
 
# exports the dataframe into excel file with
# specified name.
#excl_merged.to_excel('total_food_sales.xlsx', index=False)
